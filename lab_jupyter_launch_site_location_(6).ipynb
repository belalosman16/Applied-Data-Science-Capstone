# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Launch Sites Locations Analysis with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
# - **TASK 1:** Mark all launch sites on a map
# - **TASK 2:** Mark the success/failed launches for each site on the map
# - **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
# !pip3 install folium
# !pip3 install wget
# Out:
# Requirement already satisfied: folium in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from folium) (1.21.6)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from folium) (2023.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from requests->folium) (2024.7.4)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (pyproject.toml): started
#   Building wheel for wget (pyproject.toml): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=54727bb66b37c3b1e9f307ea481849ac1604b49d62124016ccbed3f9009b9a1e
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\a1\b6\7c\0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import folium
import wget
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/DV0101EN-3-5-1-Generating-Maps-in-Python-py-v2.0.ipynb)

# %% [markdown]
# ## Task 1: Mark all launch sites on a map

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
spacex_csv_file = wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')
spacex_df=pd.read_csv(spacex_csv_file)

# %%
spacex_df.head()
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_750079041120512b78aa5eef98cebf2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_750079041120512b78aa5eef98cebf2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_750079041120512b78aa5eef98cebf2c = L.map(
#                 &quot;map_750079041120512b78aa5eef98cebf2c&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeaad08b5ec482fe0a362d17231bc181 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eeaad08b5ec482fe0a362d17231bc181.addTo(map_750079041120512b78aa5eef98cebf2c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_750079041120512b78aa5eef98cebf2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_750079041120512b78aa5eef98cebf2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_750079041120512b78aa5eef98cebf2c = L.map(
#                 &quot;map_750079041120512b78aa5eef98cebf2c&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeaad08b5ec482fe0a362d17231bc181 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eeaad08b5ec482fe0a362d17231bc181.addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#             tile_layer_eeaad08b5ec482fe0a362d17231bc181.addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#             var circle_e5009f36433599de55d9b093d516afed = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#         var popup_af39ad1e8cbb2df04018136d8f6b07d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_575699b6bcab720c04b68338c82c0fb4 = $(`&lt;div id=&quot;html_575699b6bcab720c04b68338c82c0fb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_af39ad1e8cbb2df04018136d8f6b07d3.setContent(html_575699b6bcab720c04b68338c82c0fb4);
#
#
#
#         circle_e5009f36433599de55d9b093d516afed.bindPopup(popup_af39ad1e8cbb2df04018136d8f6b07d3)
#         ;
#
#
#
#
#             var marker_50919701cd7d41785aa43fddd1f483ee = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#             var div_icon_599c672a9161a59ba48d6c7f695489e1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_50919701cd7d41785aa43fddd1f483ee.setIcon(div_icon_599c672a9161a59ba48d6c7f695489e1);
#
#
#             tile_layer_eeaad08b5ec482fe0a362d17231bc181.addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#             var circle_b6b68220f608c48960545463a82abaaa = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#         var popup_47bb6fe32b6d4ef46dae00d7fba59ea2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1cc55b3724be1b3909f24005c6c9ad1 = $(`&lt;div id=&quot;html_c1cc55b3724be1b3909f24005c6c9ad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_47bb6fe32b6d4ef46dae00d7fba59ea2.setContent(html_c1cc55b3724be1b3909f24005c6c9ad1);
#
#
#
#         circle_b6b68220f608c48960545463a82abaaa.bindPopup(popup_47bb6fe32b6d4ef46dae00d7fba59ea2)
#         ;
#
#
#
#
#             var marker_bc444f38eff1af30811def02129d9917 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_750079041120512b78aa5eef98cebf2c);
#
#
#             var div_icon_c79112c0575f9dd55fd485556f510bea = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_bc444f38eff1af30811def02129d9917.setIcon(div_icon_c79112c0575f9dd55fd485556f510bea);
#
# &lt;/script&gt;
# &lt;/html

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# _TODO:_  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label

# %%
for launch ,lat ,long in zip(launch_sites_df["Launch Site"] ,launch_sites_df["Lat"] ,launch_sites_df["Long"]):
    circle=folium.Circle([lat,long] ,radius=1000 ,color="#000000" ,fill=True).add_child(folium.Popup(f"{launch}"))
    marker=folium.map.Marker(
        [lat,long],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % launch,
        )
    )
    site_map.add_child(circle)
    site_map.add_child(marker)

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37c14ca5e9ab1643be4121377c850a36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37c14ca5e9ab1643be4121377c850a36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37c14ca5e9ab1643be4121377c850a36 = L.map(
#                 &quot;map_37c14ca5e9ab1643be4121377c850a36&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17fbbe7ef49393a9267d01e1f32cd66f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17fbbe7ef49393a9267d01e1f32cd66f.addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             tile_layer_17fbbe7ef49393a9267d01e1f32cd66f.addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var circle_45a1285df0b033a7b3b1104bf6d0b61f = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#         var popup_7e3c011fa599b6d5365d61ff5c88cc42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f62c9bed8155ef11afb82e4ca78a2d45 = $(`&lt;div id=&quot;html_f62c9bed8155ef11afb82e4ca78a2d45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;launch&lt;/div&gt;`)[0];
#                 popup_7e3c011fa599b6d5365d61ff5c88cc42.setContent(html_f62c9bed8155ef11afb82e4ca78a2d45);
#
#
#
#         circle_45a1285df0b033a7b3b1104bf6d0b61f.bindPopup(popup_7e3c011fa599b6d5365d61ff5c88cc42)
#         ;
#
#
#
#
#             var marker_19a850232e8b1bde68693de02bdab0c3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var div_icon_98a2ee21905ea9ae72c65a667caf24ad = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_19a850232e8b1bde68693de02bdab0c3.setIcon(div_icon_98a2ee21905ea9ae72c65a667caf24ad);
#
#
#             var circle_96430599d71e3a323866d94ec3375a9c = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#         var popup_a9159d2c5b5e358569d816ec70c86487 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34a213277995a1e5a2c778fe3b766950 = $(`&lt;div id=&quot;html_34a213277995a1e5a2c778fe3b766950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;launch&lt;/div&gt;`)[0];
#                 popup_a9159d2c5b5e358569d816ec70c86487.setContent(html_34a213277995a1e5a2c778fe3b766950);
#
#
#
#         circle_96430599d71e3a323866d94ec3375a9c.bindPopup(popup_a9159d2c5b5e358569d816ec70c86487)
#         ;
#
#
#
#
#             var marker_abef725c021f1bbf4f1e249f5dcfedba = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var div_icon_11088b5ce781713c89ef9ba55fadec44 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_abef725c021f1bbf4f1e249f5dcfedba.setIcon(div_icon_11088b5ce781713c89ef9ba55fadec44);
#
#
#             var circle_dbbb30da27956b60de7c84e8116baa7a = L.circle(
#                 [28.57325457, -80.64689529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;d

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
# - Are all launch sites in proximity to the Equator line?
# - Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %% [markdown]
# # Task 2: Mark the success/failed launches for each site on the map

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# _TODO:_ Create a new column in `launch_sites` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red

# %%
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %%
for index, record in spacex_df.iterrows():
    print(record)
# Out:
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 0, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 1, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 2, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 3, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 4, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 5, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 6, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 7, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 8, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 9, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 10, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 11, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 12, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 13, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 14, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 15, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 16, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 17, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 18, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 19, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 20, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 21, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 22, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     0
# marker_color            red
# Name: 23, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 24, dtype: object
# Launch Site     CCAFS LC-40
# Lat               28.562302
# Long             -80.577356
# class                     1
# marker_color          green
# Name: 25, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     0
# marker_color            red
# Name: 26, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     0
# marker_color            red
# Name: 27, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     1
# marker_color          green
# Name: 28, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     1
# marker_color          green
# Name: 29, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     1
# marker_color          green
# Name: 30, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     1
# marker_color          green
# Name: 31, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     0
# marker_color            red
# Name: 32, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     0
# marker_color            red
# Name: 33, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     0
# marker_color            red
# Name: 34, dtype: object
# Launch Site     VAFB SLC-4E
# Lat               34.632834
# Long            -120.610745
# class                     0
# marker_color            red
# Name: 35, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 36, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    0
# marker_color           red
# Name: 37, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 38, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 39, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    0
# marker_color           red
# Name: 40, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 41, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 42, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    0
# marker_color           red
# Name: 43, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 44, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 45, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 46, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 47, dtype: object
# Launch Site     KSC LC-39A
# Lat              28.573255
# Long            -80.646895
# class                    1
# marker_color         green
# Name: 48, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      1
# marker_color           green
# Name: 49, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      1
# marker_color           green
# Name: 50, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      0
# marker_color             red
# Name: 51, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      0
# marker_color             red
# Name: 52, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      0
# marker_color             red
# Name: 53, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      1
# marker_color           green
# Name: 54, dtype: object
# Launch Site     CCAFS SLC-40
# Lat                28.563197
# Long               -80.57682
# class                      0
# marker_color             red
# Name: 55, dtype: object

# %% [markdown]
# _TODO:_ For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    marker = folium.Marker(
        location=[record['Lat'], record['Long']],
        icon=folium.Icon(color=record.marker_color, icon='rocket', prefix='fa'),
        popup=folium.Popup(record["Launch Site"], parse_html=True)
    )
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37c14ca5e9ab1643be4121377c850a36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37c14ca5e9ab1643be4121377c850a36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37c14ca5e9ab1643be4121377c850a36 = L.map(
#                 &quot;map_37c14ca5e9ab1643be4121377c850a36&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17fbbe7ef49393a9267d01e1f32cd66f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17fbbe7ef49393a9267d01e1f32cd66f.addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             tile_layer_17fbbe7ef49393a9267d01e1f32cd66f.addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var circle_45a1285df0b033a7b3b1104bf6d0b61f = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#         var popup_7e3c011fa599b6d5365d61ff5c88cc42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f62c9bed8155ef11afb82e4ca78a2d45 = $(`&lt;div id=&quot;html_f62c9bed8155ef11afb82e4ca78a2d45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;launch&lt;/div&gt;`)[0];
#                 popup_7e3c011fa599b6d5365d61ff5c88cc42.setContent(html_f62c9bed8155ef11afb82e4ca78a2d45);
#
#
#
#         circle_45a1285df0b033a7b3b1104bf6d0b61f.bindPopup(popup_7e3c011fa599b6d5365d61ff5c88cc42)
#         ;
#
#
#
#
#             var marker_19a850232e8b1bde68693de02bdab0c3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var div_icon_98a2ee21905ea9ae72c65a667caf24ad = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_19a850232e8b1bde68693de02bdab0c3.setIcon(div_icon_98a2ee21905ea9ae72c65a667caf24ad);
#
#
#             var circle_96430599d71e3a323866d94ec3375a9c = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#         var popup_a9159d2c5b5e358569d816ec70c86487 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34a213277995a1e5a2c778fe3b766950 = $(`&lt;div id=&quot;html_34a213277995a1e5a2c778fe3b766950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;launch&lt;/div&gt;`)[0];
#                 popup_a9159d2c5b5e358569d816ec70c86487.setContent(html_34a213277995a1e5a2c778fe3b766950);
#
#
#
#         circle_96430599d71e3a323866d94ec3375a9c.bindPopup(popup_a9159d2c5b5e358569d816ec70c86487)
#         ;
#
#
#
#
#             var marker_abef725c021f1bbf4f1e249f5dcfedba = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var div_icon_11088b5ce781713c89ef9ba55fadec44 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:  ',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37c14ca5e9ab1643be4121377c850a36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37c14ca5e9ab1643be4121377c850a36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37c14ca5e9ab1643be4121377c850a36 = L.map(
#                 &quot;map_37c14ca5e9ab1643be4121377c850a36&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17fbbe7ef49393a9267d01e1f32cd66f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17fbbe7ef49393a9267d01e1f32cd66f.addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             tile_layer_17fbbe7ef49393a9267d01e1f32cd66f.addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var circle_45a1285df0b033a7b3b1104bf6d0b61f = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#         var popup_7e3c011fa599b6d5365d61ff5c88cc42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f62c9bed8155ef11afb82e4ca78a2d45 = $(`&lt;div id=&quot;html_f62c9bed8155ef11afb82e4ca78a2d45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;launch&lt;/div&gt;`)[0];
#                 popup_7e3c011fa599b6d5365d61ff5c88cc42.setContent(html_f62c9bed8155ef11afb82e4ca78a2d45);
#
#
#
#         circle_45a1285df0b033a7b3b1104bf6d0b61f.bindPopup(popup_7e3c011fa599b6d5365d61ff5c88cc42)
#         ;
#
#
#
#
#             var marker_19a850232e8b1bde68693de02bdab0c3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#             var div_icon_98a2ee21905ea9ae72c65a667caf24ad = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_19a850232e8b1bde68693de02bdab0c3.setIcon(div_icon_98a2ee21905ea9ae72c65a667caf24ad);
#
#
#             var circle_96430599d71e3a323866d94ec3375a9c = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_37c14ca5e9ab1643be4121377c850a36);
#
#
#         var popup_a9159d2c5b5e358569d816ec70c86487 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34a213277995a1e5a2c778fe3b766950 = $(`&lt;div id=&quot;html_34a213277995a1e5a2c778fe3b766950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;launch&lt;/div&gt;`)[0];
#                 popup_a9159d2c5b5e358569d816ec70c86487.setContent(html_34a213277995a1e5a2c778fe3b766950);
#
#
#
#         circle_96430599d71e3a323866d94ec3375a9c.bindPopup(popup_a9159d2c5b5e358569d816ec70c86487)
#         ;
#
#
#
#
#             var marker_abef725c021f1bbf4f1e249f5dcfedba = L.marker(
#                 [28.56319718, -80.57682003],
#                 {}

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# You can calculate the distance between two points on the map based on their `Lat` and `Long` values using the following method:

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# _TODO:_ Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
import folium
from folium.plugins import MousePosition

# Create a map centered on the launch site
launch_site_lat = 28.563197
launch_site_lon = -80.576820
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=10)

# Add MousePosition to the map
MousePosition().add_to(site_map)

# Display the map to find the coordinates of the closest coastline
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6c6cc49c5c80f2496cca9cedee1672f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6c6cc49c5c80f2496cca9cedee1672f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6c6cc49c5c80f2496cca9cedee1672f = L.map(
#                 &quot;map_e6c6cc49c5c80f2496cca9cedee1672f&quot;,
#                 {
#                     center: [28.56367, -80.57163],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a5ccd12e2796010fe42e2c3d01f125b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a5ccd12e2796010fe42e2c3d01f125b.addTo(map_e6c6cc49c5c80f2496cca9cedee1672f);
#
#
#             var mouse_position_f995ddb06071d6612e23b35a31a236e8 = new L.Control.MousePosition(
#                 {&quot;emptyString&quot;: &quot;Unavailable&quot;, &quot;lngFirst&quot;: false, &quot;numDigits&quot;: 5, &quot;position&quot;: &quot;bottomright&quot;, &quot;prefix&quot;: &quot;&quot;, &quot;separator&quot;: &quot; : &quot;}
#             );
#             mouse_position_f995ddb06071d6612e23b35a31a236e8.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_f995ddb06071d6612e23b35a31a236e8.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_e6c6cc49c5c80f2496cca9cedee1672f.addControl(mouse_position_f995ddb06071d6612e23b35a31a236e8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)
coastline_lat = 28.5623  # Replace with the actual latitude from MousePosition
coastline_lon = -80.5674  # Replace with the actual longitude from MousePosition

distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

print(f"Distance from launch site to the closest coastline: {distance_coastline:.2f} km")
# Out:
# Distance from launch site to the closest coastline: 0.44 km

# %% [markdown]
# _TODO:_ After obtained its coordinate, create a `folium.Marker` to show the distance

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
distance_marker = folium.Marker(
   [coastline_lat ,coastline_lon],
   icon=DivIcon(
       icon_size=(20,20),
       icon_anchor=(0,0),
       html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
       )
   )
site_map.add_child(distance_marker)
line = folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]], weight=2)
site_map.add_child(line)

# Display the updated map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6c6cc49c5c80f2496cca9cedee1672f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6c6cc49c5c80f2496cca9cedee1672f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6c6cc49c5c80f2496cca9cedee1672f = L.map(
#                 &quot;map_e6c6cc49c5c80f2496cca9cedee1672f&quot;,
#                 {
#                     center: [28.56367, -80.57163],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a5ccd12e2796010fe42e2c3d01f125b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a5ccd12e2796010fe42e2c3d01f125b.addTo(map_e6c6cc49c5c80f2496cca9cedee1672f);
#
#
#             var mouse_position_f995ddb06071d6612e23b35a31a236e8 = new L.Control.MousePosition(
#                 {&quot;emptyString&quot;: &quot;Unavailable&quot;, &quot;lngFirst&quot;: false, &quot;numDigits&quot;: 5, &quot;position&quot;: &quot;bottomright&quot;, &quot;prefix&quot;: &quot;&quot;, &quot;separator&quot;: &quot; : &quot;}
#             );
#             mouse_position_f995ddb06071d6612e23b35a31a236e8.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_f995ddb06071d6612e23b35a31a236e8.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_e6c6cc49c5c80f2496cca9cedee1672f.addControl(mouse_position_f995ddb06071d6612e23b35a31a236e8);
#
#
#             tile_layer_9a5ccd12e2796010fe42e2c3d01f125b.addTo(map_e6c6cc49c5c80f2496cca9cedee1672f);
#
#
#             var marker_0218a0d4ab454c37af96763428bcc958 = L.marker(
#                 [28.5623, -80.5674],
#                 {}
#             ).addTo(map_e6c6cc49c5c80f2496cca9cedee1672f);
#
#
#             var div_icon_8c97193dc466f3c1c191423ddcea4142 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e      0.44 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_0218a0d4ab454c37af96763428bcc958.setIcon(div_icon_8c97193dc466f3c1c191423ddcea4142);
#
#
#             var poly_line_f346d8d7875b2c19c7945de519545205 = L.polyline(
#                 [[28.56367, -80.57163], [28.5623, -80.5674]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e6c6cc49c5c80f2496cca9cedee1672f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# _TODO:_ Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# lines=folium.PolyLine(locations=coordinates, weight=1)
# site_map.add_child(lines)

# Coordinates of the launch site
launch_site_lat = 28.563197  # Example latitude of the launch site
launch_site_lon = -80.576820  # Example longitude of the launch site

# Coordinates of the closest coastline point
coastline_lat = 28.5623  # Replace with actual latitude of the closest coastline
coastline_lon = -80.5674  # Replace with actual longitude of the closest coastline

# Create a map centered on the launch site
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=10)

# Add MousePosition to the map (optional, for reference)
MousePosition().add_to(site_map)

# Add a marker for the launch site
launch_site_marker = folium.Marker(
    [launch_site_lat, launch_site_lon],
    icon=folium.Icon(color='blue', icon='info-sign'),
    popup="Launch Site"
)
site_map.add_child(launch_site_marker)

# Add a marker for the closest coastline point
coastline_marker = folium.Marker(
    [coastline_lat, coastline_lon],
    icon=folium.Icon(color='green', icon='info-sign'),
    popup="Closest Coastline Point"
)
site_map.add_child(coastline_marker)

# Draw a PolyLine between the launch site and the coastline point
line = folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]], weight=2, color='red')
site_map.add_child(line)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e40d9a9bcbfdb10475cfbb5a581da59b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e40d9a9bcbfdb10475cfbb5a581da59b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e40d9a9bcbfdb10475cfbb5a581da59b = L.map(
#                 &quot;map_e40d9a9bcbfdb10475cfbb5a581da59b&quot;,
#                 {
#                     center: [28.563197, -80.57682],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2590d9d95af5dde8f070ad3effe6ec3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2590d9d95af5dde8f070ad3effe6ec3c.addTo(map_e40d9a9bcbfdb10475cfbb5a581da59b);
#
#
#             var mouse_position_16c9668b5a4d308e5c42a848041238c5 = new L.Control.MousePosition(
#                 {&quot;emptyString&quot;: &quot;Unavailable&quot;, &quot;lngFirst&quot;: false, &quot;numDigits&quot;: 5, &quot;position&quot;: &quot;bottomright&quot;, &quot;prefix&quot;: &quot;&quot;, &quot;separator&quot;: &quot; : &quot;}
#             );
#             mouse_position_16c9668b5a4d308e5c42a848041238c5.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_16c9668b5a4d308e5c42a848041238c5.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_e40d9a9bcbfdb10475cfbb5a581da59b.addControl(mouse_position_16c9668b5a4d308e5c42a848041238c5);
#
#
#             var marker_83f7f949595fe208dcbfd5280e44e61a = L.marker(
#                 [28.563197, -80.57682],
#                 {}
#             ).addTo(map_e40d9a9bcbfdb10475cfbb5a581da59b);
#
#
#             var icon_98de75816d0865f5802af2b232a8dc12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83f7f949595fe208dcbfd5280e44e61a.setIcon(icon_98de75816d0865f5802af2b232a8dc12);
#
#
#         var popup_cbbfabb3cf76ac4e229ec0ad3199f2e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0cbe97bfb900f5534d86d56625bd4e4e = $(`&lt;div id=&quot;html_0cbe97bfb900f5534d86d56625bd4e4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_cbbfabb3cf76ac4e229ec0ad3199f2e4.setContent(html_0cbe97bfb900f5534d86d56625bd4e4e);
#
#
#
#         marker_83f7f949595fe208dcbfd5280e44e61a.bindPopup(popup_cbbfabb3cf76ac4e229ec0ad3199f2e4)
#         ;
#
#
#
#
#             var marker_ae2af4adf578989555004ac63aeec4df = L.marker(
#                 [28.5623, -80.5674],
#                 {}
#             ).addTo(map_e40d9a9bcbfdb10475cfbb5a581da59b);
#
#
#             var icon_eecc15df928110f6469e1c5c43a7f1ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae2af4adf578989555004ac63aeec4df.setIcon(icon_eecc15df928110f6469e1c5c43a7f1ea);
#
#
#         var popup_2badd6bb6265ddb8922626e8b5dc13db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16d713c95d1cfef13a215ff925cb050b = $(`&lt;div id=&quot;html_16d713c95d1cfef13a215ff925cb050b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Closest Coastline Point&lt;/div&gt;`)[0];
#                 popup_2badd6bb6265ddb8922626e8b5dc13db.setContent(html_16d713c95d1cfef13a215ff925cb050b);
#
#
#
#         marker_ae2af4adf578989555004ac63aeec4df.bindPopup(popup_2badd6bb6265ddb8922626e8b5dc13db)
#         ;
#
#
#
#
#             var poly_line_fd70772f8378c2494a80c6782701f752 = L.polyline(
#                 [[28.563197, -80.57682], [28.5623, -80.5674]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).a

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# _TODO:_ Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %%
# Define the launch site coordinates
launch_site_lat = 28.563197  # Example latitude of the launch site
launch_site_lon = -80.576820  # Example longitude of the launch site

# Define coordinates for closest city, railway, and highway
closest_city_lat = 28.4012   # Replace with actual latitude of the closest city
closest_city_lon = -80.6043  # Replace with actual longitude of the closest city

closest_railway_lat = 28.5721   # Replace with actual latitude of the closest railway
closest_railway_lon = -80.5853  # Replace with actual longitude of the closest railway

closest_highway_lat = 28.5553   # Replace with actual latitude of the closest highway
closest_highway_lon = -80.5900  # Replace with actual longitude of the closest highway

# Create the map centered on the launch site
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=10)

# Calculate distances
distance_to_city = calculate_distance(launch_site_lat, launch_site_lon, closest_city_lat, closest_city_lon)
distance_to_railway = calculate_distance(launch_site_lat, launch_site_lon, closest_railway_lat, closest_railway_lon)
distance_to_highway = calculate_distance(launch_site_lat, launch_site_lon, closest_highway_lat, closest_highway_lon)

# Add markers with distances
city_marker = folium.Marker(
    [closest_city_lat, closest_city_lon],
    icon=DivIcon(
        icon_size=(150, 36),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12; color:#d35400;"><b>City: {:.2f} KM</b></div>'.format(distance_to_city),
    )
)
site_map.add_child(city_marker)

railway_marker = folium.Marker(
    [closest_railway_lat, closest_railway_lon],
    icon=DivIcon(
        icon_size=(150, 36),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12; color:#d35400;"><b>Railway: {:.2f} KM</b></div>'.format(distance_to_railway),
    )
)
site_map.add_child(railway_marker)

highway_marker = folium.Marker(
    [closest_highway_lat, closest_highway_lon],
    icon=DivIcon(
        icon_size=(150, 36),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12; color:#d35400;"><b>Highway: {:.2f} KM</b></div>'.format(distance_to_highway),
    )
)
site_map.add_child(highway_marker)

# Draw PolyLines between the launch site and the points of interest
city_line = folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [closest_city_lat, closest_city_lon]], weight=2, color='blue')
site_map.add_child(city_line)

railway_line = folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [closest_railway_lat, closest_railway_lon]], weight=2, color='green')
site_map.add_child(railway_line)

highway_line = folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [closest_highway_lat, closest_highway_lon]], weight=2, color='red')
site_map.add_child(highway_line)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af8762254f93506056b6d1b6f3052524 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af8762254f93506056b6d1b6f3052524&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af8762254f93506056b6d1b6f3052524 = L.map(
#                 &quot;map_af8762254f93506056b6d1b6f3052524&quot;,
#                 {
#                     center: [28.563197, -80.57682],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2963e209e62001683f1251d60467ca9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2963e209e62001683f1251d60467ca9c.addTo(map_af8762254f93506056b6d1b6f3052524);
#
#
#             var marker_930091e28c4045a4698af22415fdeda0 = L.marker(
#                 [28.4012, -80.6043],
#                 {}
#             ).addTo(map_af8762254f93506056b6d1b6f3052524);
#
#
#             var div_icon_5f82fbc6d85786b26e0e5173c44aabe6 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCity: 18.22 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_930091e28c4045a4698af22415fdeda0.setIcon(div_icon_5f82fbc6d85786b26e0e5173c44aabe6);
#
#
#             var marker_4e781eb633cd571f28082d424287faf1 = L.marker(
#                 [28.5721, -80.5853],
#                 {}
#             ).addTo(map_af8762254f93506056b6d1b6f3052524);
#
#
#             var div_icon_6d7f0f9000726fc8b651b479ec9c30a4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eRailway: 1.29 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_4e781eb633cd571f28082d424287faf1.setIcon(div_icon_6d7f0f9000726fc8b651b479ec9c30a4);
#
#
#             var marker_89c3620af90acce2360e6f78bacc6bf6 = L.marker(
#                 [28.5553, -80.59],
#                 {}
#             ).addTo(map_af8762254f93506056b6d1b6f3052524);
#
#
#             var div_icon_b19365a0c639e738dcc11fd8dbcf45d1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eHighway: 1.56 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_89c3620af90acce2360e6f78bacc6bf6.setIcon(div_icon_b19365a0c639e738dcc11fd8dbcf45d1);
#
#
#             var poly_line_b31337e14b246ba5797d768fc18d53b5 = L.polyline(
#                 [[28.563197, -80.57682], [28.4012, -80.6043]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_af8762254f93506056b6d1b6f3052524);
#
#
#             var poly_line_4626fe5c519fa3cca5436b94d9f08020 = L.polyline(
#                 [[28.563197, -80.57682], [28.5721, -80.5853]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_af8762254f93506056b6d1b6f3052524);
#
#
#             var poly_line_ce5551c80b308ad59204e374965bd420 = L.polyline(
#                 [[28.563197, -80.57682], [28.5553, -80.59]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_af8762254f93506056b6d1b6f3052524);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;h

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
# - Are launch sites in close proximity to railways?
# - Are launch sites in close proximity to highways?
# - Are launch sites in close proximity to coastline?
# - Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Joseph Santarcangelo

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2021-05-26|1.0|Yan|Created the initial version|

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
